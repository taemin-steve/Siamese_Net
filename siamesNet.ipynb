# %%
import matplotlib.pyplot as plt
import numpy as np
import random
from PIL import Image
import PIL.ImageOps    

import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
import torchvision.utils
import torch
from torch.autograd import Variable
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %%
# Creating some helper functions
def imshow(img, text=None):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
        
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
class SiameseNetworkDataset(Dataset):
    def __init__(self,imageFolderDataset,transform=None):
        self.imageFolderDataset = imageFolderDataset    
        self.transform = transform
        
    def __getitem__(self,index):
        img0_tuple = random.choice(self.imageFolderDataset.imgs)

        #We need to approximately 50% of images to be in the same class
        should_get_same_class = random.randint(0,1) 
        if should_get_same_class:
            while True:
                #Look untill the same class image is found
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1] == img1_tuple[1]:
                    break
        else:

            while True:
                #Look untill a different class image is found
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1] != img1_tuple[1]:
                    break

        img0 = Image.open(img0_tuple[0])
        img1 = Image.open(img1_tuple[0])

        img0 = img0.convert("L")
        img1 = img1.convert("L")

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1, torch.from_numpy(np.array([int(img1_tuple[1] != img0_tuple[1])], dtype=np.float32))
    
    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %%
# Load the training dataset
folder_dataset = datasets.ImageFolder(root='./output/train')

# %%
# Resize the images and transform to tensors
transformation = transforms.Compose([transforms.Resize((100,100)),
                                     transforms.ToTensor()
                                    ])

# Initialize the network
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset,
                                        transform=transformation)

# %%
# Create a simple dataloader just for simple visualization
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=0,
                        batch_size=8)

# Extract one batch
example_batch = next(iter(vis_dataloader))

# Example batch is a list containing 2x8 images, indexes 0 and 1, an also the label
# If the label is 1, it means that it is not the same person, label is 0, same person in both images
concatenated = torch.cat((example_batch[0], example_batch[1]),0)

imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy().reshape(-1))
# Out:
# [0. 1. 0. 1. 0. 0. 1. 1.]

# %%
#create the Siamese Neural Network
class SiameseNetwork(nn.Module):

    def __init__(self):
        super(SiameseNetwork, self).__init__()

        # Setting up the Sequential of CNN Layers
        self.cnn1 = nn.Sequential(
            nn.Conv2d(1, 96, kernel_size=11,stride=4),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(3, stride=2),
            
            nn.Conv2d(96, 256, kernel_size=5, stride=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, stride=2),

            nn.Conv2d(256, 384, kernel_size=3,stride=1),
            nn.ReLU(inplace=True)
        )

        # Setting up the Fully Connected Layers
        self.fc1 = nn.Sequential(
            nn.Linear(384, 1024),
            nn.ReLU(inplace=True),
            
            nn.Linear(1024, 256),
            nn.ReLU(inplace=True),
            
            nn.Linear(256,2)
        )
        
    def forward_once(self, x):
        # This function will be called for both images
        # It's output is used to determine the similiarity
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        # In this function we pass in both images and obtain both vectors
        # which are returned
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)

        return output1, output2

# %%
# Define the Contrastive Loss Function
class ContrastiveLoss(torch.nn.Module):
    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
      # Calculate the euclidian distance and calculate the contrastive loss
        euclidean_distance = F.pairwise_distance(output1, output2, keepdim = True)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                    (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))
        return loss_contrastive

# %%
# Load the training dataset
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=0,
                        batch_size=64)

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(), lr = 0.0005 )

# %%
counter = []
loss_history = [] 
iteration_number= 0

# Iterate throught the epochs
for epoch in range(100):

    # Iterate over batches
    for i, (img0, img1, label) in enumerate(train_dataloader, 0):

        # Send the images and labels to CUDA
        img0, img1, label = img0.cuda(), img1.cuda(), label.cuda()

        # Zero the gradients
        optimizer.zero_grad()

        # Pass in the two images into the network and obtain two outputs
        output1, output2 = net(img0, img1)

        # Pass the outputs of the networks and label into the loss function
        loss_contrastive = criterion(output1, output2, label)

        # Calculate the backpropagation
        loss_contrastive.backward()

        # Optimize
        optimizer.step()

        # Every 10 batches print out the loss
        if i % 10 == 0 :
            print(f"Epoch number {epoch}\n Current loss {loss_contrastive.item()}\n")
            iteration_number += 10

            counter.append(iteration_number)
            loss_history.append(loss_contrastive.item())

show_plot(counter, loss_history)
# Out:
# Epoch number 0
#  Current loss 1.805844783782959
#
# Epoch number 0
#  Current loss 1.4706149101257324
#
# Epoch number 0
#  Current loss 0.8843874931335449
#
# Epoch number 0
#  Current loss 1.4133424758911133
#
# Epoch number 0
#  Current loss 1.1623975038528442
#
# Epoch number 1
#  Current loss 1.213488221168518
#
# Epoch number 1
#  Current loss 1.179328203201294
#
# Epoch number 1
#  Current loss 1.387798547744751
#
# Epoch number 1
#  Current loss 1.0927467346191406
#
# Epoch number 1
#  Current loss 1.1368012428283691
#
# Epoch number 2
#  Current loss 1.2519954442977905
#
# Epoch number 2
#  Current loss 1.506641149520874
#
# Epoch number 2
#  Current loss 1.0289040803909302
#
# Epoch number 2
#  Current loss 1.0346133708953857
#
# Epoch number 2
#  Current loss 1.0956404209136963
#
# Epoch number 3
#  Current loss 0.7625910639762878
#
# Epoch number 3
#  Current loss 0.8734964728355408
#
# Epoch number 3
#  Current loss 1.0737953186035156
#
# Epoch number 3
#  Current loss 0.8675633668899536
#
# Epoch number 3
#  Current loss 1.0186231136322021
#
# Epoch number 4
#  Current loss 1.1227271556854248
#
# Epoch number 4
#  Current loss 0.9109683036804199
#
# Epoch number 4
#  Current loss 1.0882899761199951
#
# Epoch number 4
#  Current loss 1.0224409103393555
#
# Epoch number 4
#  Current loss 0.7815039157867432
#
# Epoch number 5
#  Current loss 1.2278857231140137
#
# Epoch number 5
#  Current loss 0.9221569299697876
#
# Epoch number 5
#  Current loss 0.9579561948776245
#
# Epoch number 5
#  Current loss 0.8933713436126709
#
# Epoch number 5
#  Current loss 0.9654660820960999
#
# Epoch number 6
#  Current loss 0.8782695531845093
#
# Epoch number 6
#  Current loss 0.9575610160827637
#
# Epoch number 6
#  Current loss 1.0856966972351074
#
# Epoch number 6
#  Current loss 1.0627107620239258
#
# Epoch number 6
#  Current loss 1.017391324043274
#
# Epoch number 7
#  Current loss 0.952721118927002
#
# Epoch number 7
#  Current loss 0.9984095096588135
#
# Epoch number 7
#  Current loss 0.8878900408744812
#
# Epoch number 7
#  Current loss 1.0791046619415283
#
# Epoch number 7
#  Current loss 0.769080400466919
#
# Epoch number 8
#  Current loss 0.9444632530212402
#
# Epoch number 8
#  Current loss 1.0011770725250244
#
# Epoch number 8
#  Current loss 0.8904308080673218
#
# Epoch number 8
#  Current loss 0.972070038318634
#
# Epoch number 8
#  Current loss 1.058962345123291
#
# Epoch number 9
#  Current loss 1.0147051811218262
#
# Epoch number 9
#  Current loss 0.9714704155921936
#
# Epoch number 9
#  Current loss 1.0641283988952637
#
# Epoch number 9
#  Current loss 1.0119946002960205
#
# Epoch number 9
#  Current loss 1.0465350151062012
#
# Epoch number 10
#  Current loss 0.9095645546913147
#
# Epoch number 10
#  Current loss 1.1332709789276123
#
# Epoch number 10
#  Current loss 0.924613893032074
#
# Epoch number 10
#  Current loss 1.099053144454956
#
# Epoch number 10
#  Current loss 0.8655312061309814
#
# Epoch number 11
#  Current loss 0.903092086315155
#
# Epoch number 11
#  Current loss 1.0957151651382446
#
# Epoch number 11
#  Current loss 1.0592093467712402
#
# Epoch number 11
#  Current loss 1.1005066633224487
#
# Epoch number 11
#  Current loss 0.9733394384384155
#
# Epoch number 12
#  Current loss 0.8788250088691711
#
# Epoch number 12
#  Current loss 0.6642439961433411
#
# Epoch number 12
#  Current loss 1.004113793373108
#
# Epoch number 12
#  Current loss 0.95517897605896
#
# Epoch number 12
#  Current loss 1.02084219455719
#
# Epoch number 13
#  Current loss 0.9753820300102234
#
# Epoch number 13
#  Current loss 1.0608091354370117
#
# Epoch number 13
#  Current loss 0.9417421221733093
#
# Epoch number 13
#  Current loss 1.0398032665252686
#
# Epoch number 13
#  Current loss 0.9402275085449219
#
# Epoch number 14
#  Current loss 0.8912563323974609
#
# Epoch number 14
#  Current loss 0.9068028926849365
#
# Epoch number 14
#  Current loss 0.9978522062301636
#
# Epoch number 14
#  Current loss 0.7768349647521973
#
# Epoch number 14
#  Current loss 0.7558712363243103
#
# Epoch number 15
#  Current loss 0.9467988610267639
#
# Epoch number 15
#  Current loss 0.9991458058357239
#
# Epoch number 15
#  Current loss 1.0248695611953735
#
# Epoch number 15
#  Current loss 0.7298715710639954
#
# Epoch number 15
#  Current loss 1.0016353130340576
#
# Epoch number 16
#  Current loss 0.8083195090293884
#
# Epoch number 16
#  Current loss 0.8481507301330566
#
# Epoch number 16
#  Current loss 1.035379409790039
#
# Epoch number 16
#  Current loss 0.7747523784637451
#
# Epoch number 16
#  Current loss 0.8030369281768799
#
# Epoch number 17
#  Current loss 0.7887927293777466
#
# Epoch number 17
#  Current loss 0.9038747549057007
#
# Epoch number 17
#  Current loss 0.9227626323699951
#
# Epoch number 17
#  Current loss 0.9573705196380615
#
# Epoch number 17
#  Current loss 0.8414820432662964
#
# Epoch number 18
#  Current loss 0.8089570999145508
#
# Epoch number 18
#  Current loss 0.8137253522872925
#
# Epoch number 18
#  Current loss 0.9529237747192383
#
# Epoch number 18
#  Current loss 0.7783472537994385
#
# Epoch number 18
#  Current loss 0.9106045365333557
#
# Epoch number 19
#  Current loss 0.7835547924041748
#
# Epoch number 19
#  Current loss 0.7772618532180786
#
# Epoch number 19
#  Current loss 1.0134962797164917
#
# Epoch number 19
#  Current loss 0.6973945498466492
#
# Epoch number 19
#  Current loss 0.7837012410163879
#
# Epoch number 20
#  Current loss 0.6487863659858704
#
# Epoch number 20
#  Current loss 0.7160817384719849
#
# Epoch number 20
#  Current loss 0.8608614802360535
#
# Epoch number 20
#  Current loss 0.8926061391830444
#
# Epoch number 20
#  Current loss 0.8297888040542603
#
# Epoch number 21
#  Current loss 0.8175567388534546
#
# Epoch number 21
#  Current loss 0.9138796329498291
#
# Epoch number 21
#  Current loss 0.795556902885437
#
# Epoch number 21
#  Current loss 0.8643891215324402
#
# Epoch number 21
#  Current loss 0.9481422901153564
#
# Epoch number 22
#  Current loss 0.7865281701087952
#
# Epoch number 22
#  Current loss 0.7310328483581543
#
# Epoch number 22
#  Current loss 0.6902596950531006
#
# Epoch number 22
#  Current loss 0.8124642372131348
#
# Epoch number 22
#  Current loss 0.8252071142196655
#
# Epoch number 23
#  Current loss 0.8018710017204285
#
# Epoch number 23
#  Current loss 0.7116219997406006
#
# Epoch number 23
#  Current loss 0.8452611565589905
#
# Epoch number 23
#  Current loss 0.6779451370239258
#
# Epoch number 23
#  Current loss 0.4794134795665741
#
# Epoch number 24
#  Current loss 0.8437675833702087
#
# Epoch number 24
#  Current loss 0.9159035682678223
#
# Epoch number 24
#  Current loss 0.8113422989845276
#
# Epoch number 24
#  Current loss 0.770599365234375
#
# Epoch number 24
#  Current loss 0.9406092166900635
#
# Epoch number 25
#  Current loss 0.6478518843650818
#
# Epoch number 25
#  Current loss 0.561252236366272
#
# Epoch number 25
#  Current loss 0.8798470497131348
#
# Epoch number 25
#  Current loss 0.739568293094635
#
# Epoch number 25
#  Current loss 0.8436329364776611
#
# Epoch number 26
#  Current loss 0.8693735599517822
#
# Epoch number 26
#  Current loss 0.8091654777526855
#
# Epoch number 26
#  Current loss 0.7788012027740479
#
# Epoch number 26
#  Current loss 0.8180572390556335
#
# Epoch number 26
#  Current loss 0.7532620429992676
#
# Epoch number 27
#  Current loss 0.7872728705406189
#
# Epoch number 27
#  Current loss 0.6998566389083862
#
# Epoch number 27
#  Current loss 0.6798140406608582
#
# Epoch number 27
#  Current loss 0.6813710927963257
#
# Epoch number 27
#  Current loss 0.5139898657798767
#
# Epoch number 28
#  Current loss 0.5545063018798828
#
# Epoch number 28
#  Current loss 0.6896604299545288
#
# Epoch number 28
#  Current loss 0.7518165111541748
#
# Epoch number 28
#  Current loss 0.7309042811393738
#
# Epoch number 28
#  Current loss 0.720716118812561
#
# Epoch number 29
#  Current loss 0.7880916595458984
#
# Epoch number 29
#  Current loss 0.7733609080314636
#
# Epoch number 29
#  Current loss 0.7833575010299683
#
# Epoch number 29
#  Current loss 0.7865411639213562
#
# Epoch number 29
#  Current loss 0.7289125919342041
#
# Epoch number 30
#  Current loss 0.7666455507278442
#
# Epoch number 30
#  Current loss 0.7392985820770264
#
# Epoch number 30
#  Current loss 0.5973684787750244
#
# Epoch number 30
#  Current loss 0.7638861536979675
#
# Epoch number 30
#  Current loss 0.7435154914855957
#
# Epoch number 31
#  Current loss 0.6654403805732727
#
# Epoch number 31
#  Current loss 0.6056981086730957
#
# Epoch number 31
#  Current loss 0.6557822823524475
#
# Epoch number 31
#  Current loss 0.7378454208374023
#
# Epoch number 31
#  Current loss 0.6145695447921753
#
# Epoch number 32
#  Current loss 0.6692863702774048
#
# Epoch number 32
#  Current loss 0.6581112146377563
#
# Epoch number 32
#  Current loss 0.6151763200759888
#
# Epoch number 32
#  Current loss 0.6193777322769165
#
# Epoch number 32
#  Current loss 0.533647894859314
#
# Epoch number 33
#  Current loss 0.5250925421714783
#
# Epoch number 33
#  Current loss 0.5860533118247986
#
# Epoch number 33
#  Current loss 0.5760822296142578
#
# Epoch number 33
#  Current loss 0.5596219301223755
#
# Epoch number 33
#  Current loss 0.6323984861373901
#
# Epoch number 34
#  Current loss 0.5864536166191101
#
# Epoch number 34
#  Current loss 0.5757647752761841
#
# Epoch number 34
#  Current loss 0.6833693981170654
#
# Epoch number 34
#  Current loss 0.5838325619697571
#
# Epoch number 34
#  Current loss 0.583478569984436
#
# Epoch number 35
#  Current loss 0.5639070868492126
#
# Epoch number 35
#  Current loss 0.6230617761611938
#
# Epoch number 35
#  Current loss 0.5256941318511963
#
# Epoch number 35
#  Current loss 0.8037350177764893
#
# Epoch number 35
#  Current loss 0.7249394655227661
#
# Epoch number 36
#  Current loss 0.6335335969924927
#
# Epoch number 36
#  Current loss 0.7016391754150391
#
# Epoch number 36
#  Current loss 0.40346574783325195
#
# Epoch number 36
#  Current loss 0.6549093723297119
#
# Epoch number 36
#  Current loss 0.7037341594696045
#
# Epoch number 37
#  Current loss 0.7192345857620239
#
# Epoch number 37
#  Current loss 0.6231296062469482
#
# Epoch number 37
#  Current loss 0.520652711391449
#
# Epoch number 37
#  Current loss 0.5070879459381104
#
# Epoch number 37
#  Current loss 0.4503241777420044
#
# Epoch number 38
#  Current loss 0.3766401708126068
#
# Epoch number 38
#  Current loss 0.7077688574790955
#
# Epoch number 38
#  Current loss 0.6104562282562256
#
# Epoch number 38
#  Current loss 0.5564159154891968
#
# Epoch number 38
#  Current loss 0.7297424674034119
#
# Epoch number 39
#  Current loss 0.6230731010437012
#
# Epoch number 39
#  Current loss 0.546385645866394
#
# Epoch number 39
#  Current loss 0.6460393667221069
#
# Epoch number 39
#  Current loss 0.3723411560058594
#
# Epoch number 39
#  Current loss 0.5914018750190735
#
# Epoch number 40
#  Current loss 0.554025411605835
#
# Epoch number 40
#  Current loss 0.64989173412323
#
# Epoch number 40
#  Current loss 0.6354758739471436
#
# Epoch number 40
#  Current loss 0.7082564830780029
#
# Epoch number 40
#  Current loss 0.6252809762954712
#
# Epoch number 41
#  Current loss 0.5235402584075928
#
# Epoch number 41
#  Current loss 0.3979979157447815
#
# Epoch number 41
#  Current loss 0.6777895092964172
#
# Epoch number 41
#  Current loss 0.5783429741859436
#
# Epoch number 41
#  Current loss 0.3409464657306671
#
# Epoch number 42
#  Current loss 0.494295597076416
#
# Epoch number 42
#  Current loss 0.5783729553222656
#
# Epoch number 42
#  Current loss 0.5959125757217407
#
# Epoch number 42
#  Current loss 0.4423348903656006
#
# Epoch number 42
#  Current loss 0.5615386962890625
#
# Epoch number 43
#  Current loss 0.3862153887748718
#
# Epoch number 43
#  Current loss 0.324262797832489
#
# Epoch number 43
#  Current loss 0.5491077303886414
#
# Epoch number 43
#  Current loss 0.43953052163124084
#
# Epoch number 43
#  Current loss 0.38597536087036133
#
# Epoch number 44
#  Current loss 0.4869042634963989
#
# Epoch number 44
#  Current loss 0.5361806154251099
#
# Epoch number 44
#  Current loss 0.29438334703445435
#
# Epoch number 44
#  Current loss 0.40947237610816956
#
# Epoch number 44
#  Current loss 0.4071425795555115
#
# Epoch number 45
#  Current loss 0.4643164277076721
#
# Epoch number 45
#  Current loss 0.5164302587509155
#
# Epoch number 45
#  Current loss 0.4703378975391388
#
# Epoch number 45
#  Current loss 0.5672484636306763
#
# Epoch number 45
#  Current loss 0.3311976492404938
#
# Epoch number 46
#  Current loss 0.5195596218109131
#
# Epoch number 46
#  Current loss 0.391965389251709
#
# Epoch number 46
#  Current loss 0.48817628622055054
#
# Epoch number 46
#  Current loss 0.333260715007782
#
# Epoch number 46
#  Current loss 0.3501777648925781
#
# Epoch number 47
#  Current loss 0.443545937538147
#
# Epoch number 47
#  Current loss 0.3461800813674927
#
# Epoch number 47
#  Current loss 0.32490378618240356
#
# Epoch number 47
#  Current loss 0.2913017272949219
#
# Epoch number 47
#  Current loss 0.2995424270629883
#
# Epoch number 48
#  Current loss 0.25685328245162964
#
# Epoch number 48
#  Current loss 0.2996780276298523
#
# Epoch number 48
#  Current loss 0.4178329110145569
#
# Epoch number 48
#  Current loss 0.41691553592681885
#
# Epoch number 48
#  Current loss 0.3463343381881714
#
# Epoch number 49
#  Current loss 0.29258015751838684
#
# Epoch number 49
#  Current loss 0.3842000961303711
#
# Epoch number 49
#  Current loss 0.2090708613395691
#
# Epoch number 49
#  Current loss 0.26647546887397766
#
# Epoch number 49
#  Current loss 0.3223675489425659
#
# Epoch number 50
#  Current loss 0.43066415190696716
#
# Epoch number 50
#  Current loss 0.42308878898620605
#
# Epoch number 50
#  Current loss 0.43405503034591675
#
# Epoch number 50
#  Current loss 0.24384117126464844
#
# Epoch number 50
#  Current loss 0.4161648154258728
#
# Epoch number 51
#  Current loss 0.3825112581253052
#
# Epoch number 51
#  Current loss 0.2045532912015915
#
# Epoch number 51
#  Current loss 0.3533686399459839
#
# Epoch number 51
#  Current loss 0.4191526770591736
#
# Epoch number 51
#  Current loss 0.2695462703704834
#
# Epoch number 52
#  Current loss 0.26153355836868286
#
# Epoch number 52
#  Current loss 0.2090814858675003
#
# Epoch number 52
#  Current loss 0.196008563041687
#
# Epoch number 52
#  Current loss 0.3813699185848236
#
# Epoch number 52
#  Current loss 0.2249523401260376
#
# Epoch number 53
#  Current loss 0.27112212777137756
#
# Epoch number 53
#  Current loss 0.2820283770561218
#
# Epoch number 53
#  Current loss 0.36178362369537354
#
# Epoch number 53
#  Current loss 0.33104223012924194
#
# Epoch number 53
#  Current loss 0.297710657119751
#
# Epoch number 54
#  Current loss 0.2698995769023895
#
# Epoch number 54
#  Current loss 0.3441762924194336
#
# Epoch number 54
#  Current loss 0.2886279225349426
#
# Epoch number 54
#  Current loss 0.30817949771881104
#
# Epoch number 54
#  Current loss 0.18886640667915344
#
# Epoch number 55
#  Current loss 0.18351639807224274
#
# Epoch number 55
#  Current loss 0.1738375425338745
#
# Epoch number 55
#  Current loss 0.3749314844608307
#
# Epoch number 55
#  Current loss 0.20110437273979187
#
# Epoch number 55
#  Current loss 0.24016468226909637
#
# Epoch number 56
#  Current loss 0.2133377492427826
#
# Epoch number 56
#  Current loss 0.2868553698062897
#
# Epoch number 56
#  Current loss 0.28375622630119324
#
# Epoch number 56
#  Current loss 0.17191091179847717
#
# Epoch number 56
#  Current loss 0.2814193367958069
#
# Epoch number 57
#  Current loss 0.20852604508399963
#
# Epoch number 57
#  Current loss 0.1311636120080948
#
# Epoch number 57
#  Current loss 0.31745389103889465
#
# Epoch number 57
#  Current loss 0.20285531878471375
#
# Epoch number 57
#  Current loss 0.25097334384918213
#
# Epoch number 58
#  Current loss 0.12839214503765106
#
# Epoch number 58
#  Current loss 0.2872460186481476
#
# Epoch number 58
#  Current loss 0.1962023675441742
#
# Epoch number 58
#  Current loss 0.28446972370147705
#
# Epoch number 58
#  Current loss 0.2351973056793213
#
# Epoch number 59
#  Current loss 0.12578758597373962
#
# Epoch number 59
#  Current loss 0.17181436717510223
#
# Epoch number 59
#  Current loss 0.24700967967510223
#
# Epoch number 59
#  Current loss 0.21925830841064453
#
# Epoch number 59
#  Current loss 0.10713177919387817
#
# Epoch number 60
#  Current loss 0.26328349113464355
#
# Epoch number 60
#  Current loss 0.15376773476600647
#
# Epoch number 60
#  Current loss 0.14321061968803406
#
# Epoch number 60
#  Current loss 0.09226371347904205
#
# Epoch number 60
#  Current loss 0.11779676377773285
#
# Epoch number 61
#  Current loss 0.15065084397792816
#
# Epoch number 61
#  Current loss 0.08998670428991318
#
# Epoch number 61
#  Current loss 0.06063918024301529
#
# Epoch number 61
#  Current loss 0.21921290457248688
#
# Epoch number 61
#  Current loss 0.04621528834104538
#
# Epoch number 62
#  Current loss 0.19266480207443237
#
# Epoch number 62
#  Current loss 0.16605786979198456
#
# Epoch number 62
#  Current loss 0.18398965895175934
#
# Epoch number 62
#  Current loss 0.06756098568439484
#
# Epoch number 62
#  Current loss 0.11817751079797745
#
# Epoch number 63
#  Current loss 0.22260738909244537
#
# Epoch number 63
#  Current loss 0.10060473531484604
#
# Epoch number 63
#  Current loss 0.13156138360500336
#
# Epoch number 63
#  Current loss 0.2142760008573532
#
# Epoch number 63
#  Current loss 0.09598276764154434
#
# Epoch number 64
#  Current loss 0.26507776975631714
#
# Epoch number 64
#  Current loss 0.21147727966308594
#
# Epoch number 64
#  Current loss 0.1541198492050171
#
# Epoch number 64
#  Current loss 0.17755945026874542
#
# Epoch number 64
#  Current loss 0.23224692046642303
#
# Epoch number 65
#  Current loss 0.04713158309459686
#
# Epoch number 65
#  Current loss 0.39100849628448486
#
# Epoch number 65
#  Current loss 0.09878280758857727
#
# Epoch number 65
#  Current loss 0.20666727423667908
#
# Epoch number 65
#  Current loss 0.1834966540336609
#
# Epoch number 66
#  Current loss 0.1421557515859604
#
# Epoch number 66
#  Current loss 0.06305187940597534
#
# Epoch number 66
#  Current loss 0.19219954311847687
#
# Epoch number 66
#  Current loss 0.13120746612548828
#
# Epoch number 66
#  Current loss 0.1725158989429474
#
# Epoch number 67
#  Current loss 0.14600205421447754
#
# Epoch number 67
#  Current loss 0.12176690250635147
#
# Epoch number 67
#  Current loss 0.09837118536233902
#
# Epoch number 67
#  Current loss 0.12998884916305542
#
# Epoch number 67
#  Current loss 0.04788364842534065
#
# Epoch number 68
#  Current loss 0.036758601665496826
#
# Epoch number 68
#  Current loss 0.12171424925327301
#
# Epoch number 68
#  Current loss 0.04331887513399124
#
# Epoch number 68
#  Current loss 0.08904875814914703
#
# Epoch number 68
#  Current loss 0.09363134205341339
#
# Epoch number 69
#  Current loss 0.2074664831161499
#
# Epoch number 69
#  Current loss 0.021245330572128296
#
# Epoch number 69
#  Current loss 0.08723889291286469
#
# Epoch number 69
#  Current loss 0.1253829449415207
#
# Epoch number 69
#  Current loss 0.1315741240978241
#
# Epoch number 70
#  Current loss 0.09137251228094101
#
# Epoch number 70
#  Current loss 0.06937343627214432
#
# Epoch number 70
#  Current loss 0.12658439576625824
#
# Epoch number 70
#  Current loss 0.15338246524333954
#
# Epoch number 70
#  Current loss 0.11722506582736969
#
# Epoch number 71
#  Current loss 0.02687685564160347
#
# Epoch number 71
#  Current loss 0.06800415366888046
#
# Epoch number 71
#  Current loss 0.05020313337445259
#
# Epoch number 71
#  Current loss 0.05307139828801155
#
# Epoch number 71
#  Current loss 0.07313304394483566
#
# Epoch number 72
#  Current loss 0.0839170590043068
#
# Epoch number 72
#  Current loss 0.193046435713768
#
# Epoch number 72
#  Current loss 0.021188609302043915
#
# Epoch number 72
#  Current loss 0.14058664441108704
#
# Epoch number 72
#  Current loss 0.017451483756303787
#
# Epoch number 73
#  Current loss 0.13083164393901825
#
# Epoch number 73
#  Current loss 0.2450634241104126
#
# Epoch number 73
#  Current loss 0.017209183424711227
#
# Epoch number 73
#  Current loss 0.07713446766138077
#
# Epoch number 73
#  Current loss 0.03782917559146881
#
# Epoch number 74
#  Current loss 0.12082236260175705
#
# Epoch number 74
#  Current loss 0.023220451548695564
#
# Epoch number 74
#  Current loss 0.048627208918333054
#
# Epoch number 74
#  Current loss 0.063694067299366
#
# Epoch number 74
#  Current loss 0.09838855266571045
#
# Epoch number 75
#  Current loss 0.016613714396953583
#
# Epoch number 75
#  Current loss 0.040245216339826584
#
# Epoch number 75
#  Current loss 0.08417333662509918
#
# Epoch number 75
#  Current loss 0.11306442320346832
#
# Epoch number 75
#  Current loss 0.06167001649737358
#
# Epoch number 76
#  Current loss 0.11620530486106873
#
# Epoch number 76
#  Current loss 0.028765851631760597
#
# Epoch number 76
#  Current loss 0.23555324971675873
#
# Epoch number 76
#  Current loss 0.12474525719881058
#
# Epoch number 76
#  Current loss 0.023122094571590424
#
# Epoch number 77
#  Current loss 0.21702635288238525
#
# Epoch number 77
#  Current loss 0.154141366481781
#
# Epoch number 77
#  Current loss 0.09260447323322296
#
# Epoch number 77
#  Current loss 0.12933622300624847
#
# Epoch number 77
#  Current loss 0.028902534395456314
#
# Epoch number 78
#  Current loss 0.1515449434518814
#
# Epoch number 78
#  Current loss 0.04741469770669937
#
# Epoch number 78
#  Current loss 0.07584799081087112
#
# Epoch number 78
#  Current loss 0.07547131180763245
#
# Epoch number 78
#  Current loss 0.05021827295422554
#
# Epoch number 79
#  Current loss 0.18237583339214325
#
# Epoch number 79
#  Current loss 0.1118425577878952
#
# Epoch number 79
#  Current loss 0.13805337250232697
#
# Epoch number 79
#  Current loss 0.0633108839392662
#
# Epoch number 79
#  Current loss 0.0789552628993988
#
# Epoch number 80
#  Current loss 0.04339083284139633
#
# Epoch number 80
#  Current loss 0.06791700422763824
#
# Epoch number 80
#  Current loss 0.041409168392419815
#
# Epoch number 80
#  Current loss 0.13355860114097595
#
# Epoch number 80
#  Current loss 0.04575453698635101
#
# Epoch number 81
#  Current loss 0.08033891767263412
#
# Epoch number 81
#  Current loss 0.01661110669374466
#
# Epoch number 81
#  Current loss 0.09793644398450851
#
# Epoch number 81
#  Current loss 0.09815163165330887
#
# Epoch number 81
#  Current loss 0.06691104918718338
#
# Epoch number 82
#  Current loss 0.1258503645658493
#
# Epoch number 82
#  Current loss 0.16710209846496582
#
# Epoch number 82
#  Current loss 0.11864910274744034
#
# Epoch number 82
#  Current loss 0.05242422968149185
#
# Epoch number 82
#  Current loss 0.041461363434791565
#
# Epoch number 83
#  Current loss 0.14162708818912506
#
# Epoch number 83
#  Current loss 0.08815819025039673
#
# Epoch number 83
#  Current loss 0.09313306957483292
#
# Epoch number 83
#  Current loss 0.041435983031988144
#
# Epoch number 83
#  Current loss 0.06503856182098389
#
# Epoch number 84
#  Current loss 0.08396859467029572
#
# Epoch number 84
#  Current loss 0.03788008540868759
#
# Epoch number 84
#  Current loss 0.07275556772947311
#
# Epoch number 84
#  Current loss 0.07843510806560516
#
# Epoch number 84
#  Current loss 0.01938619464635849
#
# Epoch number 85
#  Current loss 0.013959841802716255
#
# Epoch number 85
#  Current loss 0.04082728922367096
#
# Epoch number 85
#  Current loss 0.012513013556599617
#
# Epoch number 85
#  Current loss 0.09049516171216965
#
# Epoch number 85
#  Current loss 0.09024422615766525
#
# Epoch number 86
#  Current loss 0.11514905095100403
#
# Epoch number 86
#  Current loss 0.04023917764425278
#
# Epoch number 86
#  Current loss 0.13358023762702942
#
# Epoch number 86
#  Current loss 0.020085684955120087
#
# Epoch number 86
#  Current loss 0.1160123273730278
#
# Epoch number 87
#  Current loss 0.07196700572967529
#
# Epoch number 87
#  Current loss 0.022891229018568993
#
# Epoch number 87
#  Current loss 0.07052986323833466
#
# Epoch number 87
#  Current loss 0.06123235821723938
#
# Epoch number 87
#  Current loss 0.09930469840765
#
# Epoch number 88
#  Current loss 0.00603810278698802
#
# Epoch number 88
#  Current loss 0.01445607841014862
#
# Epoch number 88
#  Current loss 0.06900352239608765
#
# Epoch number 88
#  Current loss 0.06558395177125931
#
# Epoch number 88
#  Current loss 0.025047490373253822
#
# Epoch number 89
#  Current loss 0.018063457682728767
#
# Epoch number 89
#  Current loss 0.08276048302650452
#
# Epoch number 89
#  Current loss 0.06222404167056084
#
# Epoch number 89
#  Current loss 0.07810625433921814
#
# Epoch number 89
#  Current loss 0.10433323681354523
#
# Epoch number 90
#  Current loss 0.11405029892921448
#
# Epoch number 90
#  Current loss 0.012683598324656487
#
# Epoch number 90
#  Current loss 0.07534027099609375
#
# Epoch number 90
#  Current loss 0.04856286570429802
#
# Epoch number 90
#  Current loss 0.011595693416893482
#
# Epoch number 91
#  Current loss 0.006906647235155106
#
# Epoch number 91
#  Current loss 0.06277833133935928
#
# Epoch number 91
#  Current loss 0.0649007260799408
#
# Epoch number 91
#  Current loss 0.008744140155613422
#
# Epoch number 91
#  Current loss 0.07215621322393417
#
# Epoch number 92
#  Current loss 0.01338657271116972
#
# Epoch number 92
#  Current loss 0.005644930526614189
#
# Epoch number 92
#  Current loss 0.13114815950393677
#
# Epoch number 92
#  Current loss 0.006114304065704346
#
# Epoch number 92
#  Current loss 0.012552340514957905
#
# Epoch number 93
#  Current loss 0.006490899715572596
#
# Epoch number 93
#  Current loss 0.06408102065324783
#
# Epoch number 93
#  Current loss 0.00262345839291811
#
# Epoch number 93
#  Current loss 0.06190170720219612
#
# Epoch number 93
#  Current loss 0.007628923282027245
#
# Epoch number 94
#  Current loss 0.009465767070651054
#
# Epoch number 94
#  Current loss 0.08362536877393723
#
# Epoch number 94
#  Current loss 0.06697096675634384
#
# Epoch number 94
#  Current loss 0.11866386979818344
#
# Epoch number 94
#  Current loss 0.007013736292719841
#
# Epoch number 95
#  Current loss 0.06367970257997513
#
# Epoch number 95
#  Current loss 0.00825099740177393
#
# Epoch number 95
#  Current loss 0.005139186047017574
#
# Epoch number 95
#  Current loss 0.06728396564722061
#
# Epoch number 95
#  Current loss 0.00821738876402378
#
# Epoch number 96
#  Current loss 0.004322384018450975
#
# Epoch number 96
#  Current loss 0.004484868608415127
#
# Epoch number 96
#  Current loss 0.05239632725715637
#
# Epoch number 96
#  Current loss 0.0070106559433043
#
# Epoch number 96
#  Current loss 0.11739344894886017
#
# Epoch number 97
#  Current loss 0.004011326469480991
#
# Epoch number 97
#  Current loss 0.0019107609987258911
#
# Epoch number 97
#  Current loss 0.0028049717657268047
#
# Epoch number 97
#  Current loss 0.002499306807294488
#
# Epoch number 97
#  Current loss 0.058145131915807724
#
# Epoch number 98
#  Current loss 0.004956396296620369
#
# Epoch number 98
#  Current loss 0.004476155620068312
#
# Epoch number 98
#  Current loss 0.0654958114027977
#
# Epoch number 98
#  Current loss 0.10279116034507751
#
# Epoch number 98
#  Current loss 0.10874763131141663
#
# Epoch number 99
#  Current loss 0.0061972481198608875
#
# Epoch number 99
#  Current loss 0.11089162528514862
#
# Epoch number 99
#  Current loss 0.05822475254535675
#
# Epoch number 99
#  Current loss 0.11326998472213745
#
# Epoch number 99
#  Current loss 0.05003172531723976

# %%
# Locate the test dataset and load it into the SiameseNetworkDataset
folder_dataset_test = datasets.ImageFolder(root="./output/val")
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
                                        transform=transformation)
test_dataloader = DataLoader(siamese_dataset, num_workers=0, batch_size=1, shuffle=True)

# Grab one image that we are going to test
dataiter = iter(test_dataloader)
x0, _, _ = next(dataiter)

for i in range(10):
    # Iterate over 10 images and test them with the first image (x0)
    _, x1, label2 = next(dataiter)

    # Concatenate the two images together
    concatenated = torch.cat((x0, x1), 0)
    
    output1, output2 = net(x0.cuda(), x1.cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated), f'Dissimilarity: {euclidean_distance.item():.2f}')
